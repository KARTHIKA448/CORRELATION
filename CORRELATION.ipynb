# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9CB9-E181
#
#  Directory of C:\Mod5-Statistics\corelation
#
# 11/04/2023  03:43 PM    <DIR>          .
# 11/04/2023  03:43 PM    <DIR>          ..
# 11/03/2023  10:00 PM    <DIR>          .ipynb_checkpoints
# 11/04/2023  12:11 PM           540,200 amazon_laptop_prices_v01.csv
# 10/26/2023  10:39 AM             3,301 car_crashes.csv
# 11/04/2023  03:43 PM           149,684 CORRELATION.ipynb
# 10/16/2023  10:53 AM         2,435,302 GlobalWeatherRepository.csv.xls
# 11/04/2023  12:05 PM         1,423,529 housing.csv
# 10/19/2023  09:43 AM           453,248 shopping_trends.csv
# 10/19/2023  09:43 AM           416,614 shopping_trends_updated.csv
# 10/26/2023  10:39 AM             9,729 tips.csv
# 10/26/2023  10:39 AM            57,018 titanic.csv
#                9 File(s)      5,488,625 bytes
#                3 Dir(s)  41,171,599,360 bytes free

# %% [markdown]
# ### TIPS

# %%
tips=pd.read_csv("tips.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips_cor = tips.corr()
tips_cor
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips_cor["total_bill"].sort_values(ascending=False)
# Out:
# total_bill    1.000000
# tip           0.675734
# size          0.598315
# Name: total_bill, dtype: float64

# %% [markdown]
#    **from tips dataset correlation:**
#
#        * tips and total bill is more related to the data,showing +ve correlation.That is when total bill increases tip also increases(in a big strength)
#         * size and tips is also related , but not much as total bill,size is showing +ve relation to total bill(not in a big strength)
#         *that is tips,size and total bill have correlation between them

# %% [markdown]
# ### TITANIC

# %%
titanic=pd.read_csv("titanic.csv")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic_cor = titanic.corr()
titanic_cor
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
titanic_cor["survived"].sort_values(ascending=False)
# Out:
# survived      1.000000
# fare          0.257307
# parch         0.081629
# sibsp        -0.035322
# age          -0.077221
# alone        -0.203367
# pclass       -0.338481
# adult_male   -0.557080
# Name: survived, dtype: float64

# %% [markdown]
#    **from titanic dataset correlation:**
#
#        survived show that:
# * survived, fare,parch shows +ve correlation.
# * sibsp,age,alone,pclass,adult_male shows -ve correlation.
# * fare is showing a very small +ve relation when the fare increase the class increase which result in the rescue faste
# * showing negative relation towards male which indicates survival rate decreased in male which indicates there are chances male taking part in rescue operation risking their own lives

# %%
titanic_cor["pclass"].sort_values(ascending=False)
# Out:
# pclass        1.000000
# alone         0.135207
# adult_male    0.094035
# sibsp         0.083081
# parch         0.018443
# survived     -0.338481
# age          -0.369226
# fare         -0.549500
# Name: pclass, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     pclass show
#         * alone,adult_male,sibsp,parch have +ve correlation with pclass
#         *survived,age,fare have -ve correlation with pclass

# %%
titanic_cor["age"].sort_values(ascending=False)
# Out:
# age           1.000000
# adult_male    0.280328
# alone         0.198270
# fare          0.096067
# survived     -0.077221
# parch        -0.189119
# sibsp        -0.308247
# pclass       -0.369226
# Name: age, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     age show
#         * alone,adult_male,fare have +ve correlation with age
#         *survived,pclass,sibsp,parch have -ve correlation with age

# %%
titanic_cor["sibsp"].sort_values(ascending=False)
# Out:
# sibsp         1.000000
# parch         0.414838
# fare          0.159651
# pclass        0.083081
# survived     -0.035322
# adult_male   -0.253586
# age          -0.308247
# alone        -0.584471
# Name: sibsp, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     sibsp show
#         * parch,fare,pclass, have +ve correlation with sibsp
#         *survived,adult_male,age,alone have -ve correlation with sibsp
#         * if the person is alone there is no chance for sibsp

# %%
titanic_cor["parch"].sort_values(ascending=False)
# Out:
# parch         1.000000
# sibsp         0.414838
# fare          0.216225
# survived      0.081629
# pclass        0.018443
# age          -0.189119
# adult_male   -0.349943
# alone        -0.583398
# Name: parch, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     parch show
#         * sibsp,fare,survived,pclass have +ve correlation with parch
#         *  showing +ve relation to sibsp which means parent or children or family present
#         * age,adult_male,alone have -ve correlation with parch
#         * showing -ve relation to alone , if the person is alone parent or children wont travel with them

# %%
titanic_cor["fare"].sort_values(ascending=False)
# Out:
# fare          1.000000
# survived      0.257307
# parch         0.216225
# sibsp         0.159651
# age           0.096067
# adult_male   -0.182024
# alone        -0.271832
# pclass       -0.549500
# Name: fare, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     fare show
#         *survived,parch,sibsp,age have +ve correlation with fare
#         *adul_male,alone,pclass have -ve correlation with fare

# %%
titanic_cor["adult_male"].sort_values(ascending=False)
# Out:
# adult_male    1.000000
# alone         0.404744
# age           0.280328
# pclass        0.094035
# fare         -0.182024
# sibsp        -0.253586
# parch        -0.349943
# survived     -0.557080
# Name: adult_male, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     adult_male show
#         * alone,age,pclass have +ve correlation with adult_male
#         * fare,sibsp,parch,survived have -ve correlation with adult_male

# %%
titanic_cor["alone"].sort_values(ascending=False)
# Out:
# alone         1.000000
# adult_male    0.404744
# age           0.198270
# pclass        0.135207
# survived     -0.203367
# fare         -0.271832
# parch        -0.583398
# sibsp        -0.584471
# Name: alone, dtype: float64

# %% [markdown]
# **from titanic dataset correlation:**
#
#     alone show
#         * adult_male,age,pclass have +ve correlation with alone
#         * survived,fare,parch,sibsp have -ve correlation with alone
#         *if the person is alone parent/children ,sibling/spouse wont travel with them

# %% [markdown]
# ### HOUSING

# %%
housing=pd.read_csv("housing.csv")
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
housing_cor=housing.corr()
housing_cor
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
housing_cor["longitude"].sort_values(ascending=False)
# Out:
# longitude             1.000000
# population            0.099773
# total_bedrooms        0.069608
# households            0.055310
# total_rooms           0.044568
# median_income        -0.015176
# median_house_value   -0.045967
# housing_median_age   -0.108197
# latitude             -0.924664
# Name: longitude, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             longitude shows:
#     * longitude is showing high negative correlation with latitude which means when latitude increases longitude decreases and vice versa
#     * population,total_bedrooms,households,total_rooms  are showing correlation as the values are more close to 0

# %%
housing_cor["latitude"].sort_values(ascending=False)
# Out:
# latitude              1.000000
# housing_median_age    0.011173
# total_rooms          -0.036100
# total_bedrooms       -0.066983
# households           -0.071035
# median_income        -0.079809
# population           -0.108785
# median_house_value   -0.144160
# longitude            -0.924664
# Name: latitude, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             latitude shows:
#     * latitude is showing negative correlation with total_rooms,total_bedrooms,households, population,median_house_value,longitude
#     * housing_median_age have less +ve correlation as the values are more close to 0
#     *showing big-ve relation to longitude

# %%
housing_cor["population"].sort_values(ascending=False)
# Out:
# population            1.000000
# households            0.907222
# total_bedrooms        0.877747
# total_rooms           0.857126
# longitude             0.099773
# median_income         0.004834
# median_house_value   -0.024650
# latitude             -0.108785
# housing_median_age   -0.296244
# Name: population, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             population shows:
#     * households,total_bedrooms,total_rooms,longitude,median_income have less +ve correlation( as population increases demands for household also increase)
#     * median_house_value,latitude,housing_median_age have small -ve correlation (age increases population decreases )

# %%
housing_cor["total_bedrooms"].sort_values(ascending=False)
# Out:
# total_bedrooms        1.000000
# households            0.979728
# total_rooms           0.930380
# population            0.877747
# longitude             0.069608
# median_house_value    0.049686
# median_income        -0.007723
# latitude             -0.066983
# housing_median_age   -0.320451
# Name: total_bedrooms, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             total_bedrooms shows:
#     * total_bedroom showing high +ve correlation to total_rooms and households( as total bedroom increases the house hold needs as well as the number of rooms increases)
#     * population,longitude,median_house_value also have +ve correlation
#     *median_income,latitude,housing_median_age have less -ve correlation

# %%
housing_cor["housing_median_age"].sort_values(ascending=False)
# Out:
# housing_median_age    1.000000
# median_house_value    0.105623
# latitude              0.011173
# longitude            -0.108197
# median_income        -0.119034
# population           -0.296244
# households           -0.302916
# total_bedrooms       -0.320451
# total_rooms          -0.361262
# Name: housing_median_age, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             housing_median_age shows:
#     * housing_median_age is showing +ve correlation with median_house_value,latitude
#     * housing_median_age have less -ve correlation  with longitude,median_income,population ,households,total_bedrooms,total_rooms

# %%
housing_cor["total_rooms"].sort_values(ascending=False)
# Out:
# total_rooms           1.000000
# total_bedrooms        0.930380
# households            0.918484
# population            0.857126
# median_income         0.198050
# median_house_value    0.134153
# longitude             0.044568
# latitude             -0.036100
# housing_median_age   -0.361262
# Name: total_rooms, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             total_rooms shows:
#     * total_bedrooms,households,population,median_income,median_house_value,longitude have +ve correlation
#     * latitude,housing_median_age have -ve correlation

# %%
housing_cor["households"].sort_values(ascending=False)
# Out:
# households            1.000000
# total_bedrooms        0.979728
# total_rooms           0.918484
# population            0.907222
# median_house_value    0.065843
# longitude             0.055310
# median_income         0.013033
# latitude             -0.071035
# housing_median_age   -0.302916
# Name: households, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             households shows:
#     * total_bedrooms,total_rooms,population,median_house_value,longitude,median_income have +ve correlation
#     * latitude,housing_median_age have -ve correlation

# %%
housing_cor["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#            median_house_value shows:
#     * showing +ve relation to income which shows the income increase result in the increased house value also
#     * total_rooms,housing_median_age,households,total_bedrooms have +ve correlation
#     * population,longitude,latitude have -ve correlation

# %%
housing_cor["median_income"].sort_values(ascending=False)
# Out:
# median_income         1.000000
# median_house_value    0.688075
# total_rooms           0.198050
# households            0.013033
# population            0.004834
# total_bedrooms       -0.007723
# longitude            -0.015176
# latitude             -0.079809
# housing_median_age   -0.119034
# Name: median_income, dtype: float64

# %% [markdown]
#    **from housing dataset**
#
#             median_income shows:
#     * median_house_value,total_rooms,total_rooms,population have +ve correlation
#     * total_bedrooms,longitude,latitude,housing_median_age have -ve correlation

# %% [markdown]
# ### CAR CRASHES

# %%
car_crashes = pd.read_csv("car_crashes.csv")
car_crashes
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
car_crashes.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
carcrashes_cor = car_crashes.corr()
carcrashes_cor
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
carcrashes_cor["total"].sort_values(ascending=False)
# Out:
# total             1.000000
# no_previous       0.956179
# alcohol           0.852613
# not_distracted    0.827560
# speeding          0.611548
# ins_losses       -0.036011
# ins_premium      -0.199702
# Name: total, dtype: float64

# %% [markdown]
#    **from car_crases dataset**
#
#        total shows:
#            * no_previous have maximum +ve correlation(strength is more)
#            * alcohol also have +ve correlation,that is when alcohol consumption increases car crash also increases
#            * not distracted also have +ve corelation,that is when the driver is not distracted opposite people/car can be a reason for car crash)
#            * speeding is showing positive corelation but the strength is less compared to the above ones,that is when the speed increase car_crash also increases
#            * ins losses ans ins premium have less -ve  correlation

# %%
carcrashes_cor["speeding"].sort_values(ascending=False)
# Out:
# speeding          1.000000
# alcohol           0.669719
# total             0.611548
# not_distracted    0.588010
# no_previous       0.571976
# ins_losses       -0.065928
# ins_premium      -0.077675
# Name: speeding, dtype: float64

# %% [markdown]
#    **from car_crases dataset**
#
#        speeding shows:
#            * alcohol also high +ve correlation,that is when alcohol consumption increases car crash also increases
#            * total is showing positive corelation after alcohol
#            * not distracted also have +ve corelation,that is when the driver is not distracted opposite people/car can be a reason for car crash)
#            * no_previous have minimum +ve correlation
#            * ins losses ans ins premium have less -ve  correlation

# %%
carcrashes_cor["alcohol"].sort_values(ascending=False)
# Out:
# alcohol           1.000000
# total             0.852613
# no_previous       0.783520
# not_distracted    0.732816
# speeding          0.669719
# ins_losses       -0.112547
# ins_premium      -0.170612
# Name: alcohol, dtype: float64

# %% [markdown]
#    **from car_crases dataset**
#
#        alcohol shows:
#            * alcohol is having high correlation with total
#            * no_previous have +ve correlation after total
#            * not distracted also have +ve corelation,that is when the driver is not distracted opposite people/car can be a reason for car crash)
#            * speeding is showing positive corelation but the strength is less compared to the above ones,that is when the speed increase car_crash also increases
#            * ins losses ans ins premium have less -ve  correlation

# %%
carcrashes_cor["not_distracted"].sort_values(ascending=False)
# Out:
# not_distracted    1.000000
# total             0.827560
# no_previous       0.747307
# alcohol           0.732816
# speeding          0.588010
# ins_losses       -0.075970
# ins_premium      -0.174856
# Name: not_distracted, dtype: float64

# %% [markdown]
#    **from car_crases dataset**
#
#        not distracted shows:
#            * not distracted having high correlation with total
#            * no_previous have +ve correlation after total
#            * alcohol also high +ve correlation,that is when alcohol consumption increases car crash also increases
#            * speeding is showing positive corelation but the strength is less compared to the above ones,that is when the speed increase car_crash also increases
#            * ins losses ans ins premium have less -ve  correlation

# %%
carcrashes_cor["no_previous"].sort_values(ascending=False)
# Out:
# no_previous       1.000000
# total             0.956179
# alcohol           0.783520
# not_distracted    0.747307
# speeding          0.571976
# ins_losses       -0.006359
# ins_premium      -0.156895
# Name: no_previous, dtype: float64

# %% [markdown]
#    **from car_crases dataset**
#
#        no_previous shows:
#             * no previous having high correlation with total
#             * alcohol also high +ve correlation,that is when alcohol consumption increases car crash also increases
#             * not distracted also have +ve corelation,that is when the driver is not distracted opposite people/car can be a reason for car crash)
#             * speeding is showing positive corelation but the strength is less compared to the above ones,that is when the speed increase car_crash also increases
#             * ins losses ans ins premium have less -ve  correlation

# %%
carcrashes_cor["ins_premium"].sort_values(ascending=False)
# Out:
# ins_premium       1.000000
# ins_losses        0.623116
# speeding         -0.077675
# no_previous      -0.156895
# alcohol          -0.170612
# not_distracted   -0.174856
# total            -0.199702
# Name: ins_premium, dtype: float64

# %% [markdown]
#    **from car_crases dataset**
#
#         ins premium shows:
#            * ins losses have maximum +ve correlation(strength is more)
#            * speeding,no previous,alcohol,not distracted,total have -ve  correlation

# %%
carcrashes_cor["ins_losses"].sort_values(ascending=False)
# Out:
# ins_losses        1.000000
# ins_premium       0.623116
# no_previous      -0.006359
# total            -0.036011
# speeding         -0.065928
# not_distracted   -0.075970
# alcohol          -0.112547
# Name: ins_losses, dtype: float64

# %% [markdown]
#      **from car_crases dataset**
#
#         ins losses shows:
#            * ins premium have maximum +ve correlation(strength is more)
#            * speeding,no previous,alcohol,not distracted,total have -ve  correlation

# %% [markdown]
# ### TRENDS

# %%
trends = pd.read_csv("shopping_trends.csv",index_col=0)
trends
# Out:
#              Age  Gender Item Purchased     Category  Purchase Amount (USD)  \
# Customer ID
# 1             55    Male         Blouse     Clothing                     53
# 2             19    Male        Sweater     Clothing                     64
# 3             50    Male          Jeans     Clothing                     73
# 4             21    Male        Sandals     Footwear                     90
# 5             45    Male         Blouse     Clothing                     49
# ...          ...     ...            ...          ...                    ...
# 3896          40  Female         Hoodie     Clothing                     28
# 3897          52  Female       Backpack  Accessories                     49
# 3898          46  Female           Belt  Accessories                     33
# 3899          44  Female          Shoes     Footwear                     77
# 3900          52  Female        Handbag  Accessories                     81
#
# ...

# %%
trends.columns
# Out:
# Index(['Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)',
#        'Location', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
trends_corr=trends.corr()
trends_corr
# Out:
#                             Age  Purchase Amount (USD)  Review Rating  \
# Age                    1.000000              -0.010424      -0.021949
# Purchase Amount (USD) -0.010424               1.000000       0.030776
# Review Rating         -0.021949               0.030776       1.000000
# Previous Purchases     0.040445               0.008063       0.004229
#
#                        Previous Purchases
# Age                              0.040445
# Purchase Amount (USD)            0.008063
# Review Rating                    0.004229
# Previous Purchases               1.000000

# %%
trends_corr["Age"].sort_values(ascending=False)
# Out:
# Age                      1.000000
# Previous Purchases       0.040445
# Purchase Amount (USD)   -0.010424
# Review Rating           -0.021949
# Name: Age, dtype: float64

# %% [markdown]
# **from trends dataset**
#
#     Age shows:
#        * none of the points are showing correlation as the values are more close to 0

# %%
trends_corr["Purchase Amount (USD)"].sort_values(ascending=False)
# Out:
# Purchase Amount (USD)    1.000000
# Review Rating            0.030776
# Previous Purchases       0.008063
# Age                     -0.010424
# Name: Purchase Amount (USD), dtype: float64

# %% [markdown]
# **from trends dataset**
#
#     Purchase Amount (USD) shows:
#        * none of the points are showing correlation as the values are more close to 0

# %%
trends_corr["Review Rating"].sort_values(ascending=False)
# Out:
# Review Rating            1.000000
# Purchase Amount (USD)    0.030776
# Previous Purchases       0.004229
# Age                     -0.021949
# Name: Review Rating, dtype: float64

# %% [markdown]
# **from trends dataset**
#
#     Review Rating shows:
#        * none of the points are showing correlation as the values are more close to 0

# %%
trends_corr["Previous Purchases"].sort_values(ascending=False)
# Out:
# Previous Purchases       1.000000
# Age                      0.040445
# Purchase Amount (USD)    0.008063
# Review Rating            0.004229
# Name: Previous Purchases, dtype: float64

# %% [markdown]
# **from trends dataset**
#
#     Previous Purchases shows:
#        * none of the points are showing correlation as the values are more close to 0

# %% [markdown]
# ### LAPTOP

# %%
laptop = pd.read_csv("amazon_laptop_prices_v01.csv",index_col=0)
laptop
# Out:
#                         model   screen_size       color harddisk  \
# brand
# ROKC                      NaN     14 Inches        Blue  1000 GB
# HP                        NaN   15.6 Inches      Silver  1000 GB
# MSI     Vector GP66 12UGS-267  15.66 Inches  Core Black      NaN
# Apple             MacBook Air   13.3 Inches      Silver   256 GB
# Apple             MacBook Air   15.3 Inches    Midnight   256 GB
# ...                       ...           ...         ...      ...
# MSI    Stealth GS66 12UGS-025   15.6 Inches  Core Black      NaN
# ROKC                      NaN     14 Inches        Blue  1000 GB
# Dell     Inspiron 3511 Laptop   15.6 Inches       Black   512 GB
# Dell     Latitude 3420 Laptop     14 Inches         NaN   512 GB
# Dell     Latitude 5430 Laptop     14 Inches       Black   256 GB
#
#                  cpu    ram               OS  special_features    graphics  \
# brand
# ROKC   Intel Core i7   8 GB       Windows 11               NaN  Integrated
# ...

# %%
laptop_corr=laptop.corr()
laptop_corr
# Out:
#         rating
# rating     1.0

# %%
laptop_corr["rating"].sort_values(ascending=False)
# Out:
# rating    1.0
# Name: rating, dtype: float64

# %% [markdown]
# there is no other feature to relate

# %% [markdown]
# ### WEATHER

# %%
weather = pd.read_csv("GlobalWeatherRepository.csv.xls",index_col=[0])
weather
# Out:
#                 location_name  latitude  longitude         timezone  \
# country
# Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# Albania                Tirana     41.33      19.82    Europe/Tirane
# Algeria               Algiers     36.76       3.05   Africa/Algiers
# Andorra      Andorra La Vella     42.50       1.52   Europe/Andorra
# Angola                 Luanda     -8.84      13.23    Africa/Luanda
# ...                       ...       ...        ...              ...
# Venezuela             Caracas     10.50     -66.92  America/Caracas
# Vietnam                 Hanoi     21.03     105.85     Asia/Bangkok
# Yemen                   Sanaa     15.35      44.21        Asia/Aden
# Zambia                 Lusaka    -15.42      28.28    Africa/Lusaka
# Zimbabwe               Harare    -17.82      31.04    Africa/Harare
#
#              last_updated_epoch      last_updated  temperature_celsius  \
# country
# ...

# %%
weather_corr = weather.corr()
weather_corr
# Out:
#                               latitude  longitude  last_updated_epoch  \
# latitude                      1.000000  -0.013652           -0.000265
# longitude                    -0.013652   1.000000            0.000785
# last_updated_epoch           -0.000265   0.000785            1.000000
# temperature_celsius          -0.343188  -0.152681           -0.072088
# temperature_fahrenheit       -0.343211  -0.152685           -0.072083
# wind_mph                     -0.089537  -0.125799            0.022586
# wind_kph                     -0.089568  -0.125923            0.022797
# wind_degree                   0.104342   0.002040            0.020470
# pressure_mb                   0.071149  -0.008029            0.075125
# pressure_in                   0.071993  -0.006817            0.076631
# precip_mm                    -0.034173  -0.028194           -0.034370
# precip_in                    -0.033135  -0.028390           -0.033960
# ...

# %%
weather_corr.columns
# Out:
# Index(['latitude', 'longitude', 'last_updated_epoch', 'temperature_celsius',
#        'temperature_fahrenheit', 'wind_mph', 'wind_kph', 'wind_degree',
#        'pressure_mb', 'pressure_in', 'precip_mm', 'precip_in', 'humidity',
#        'cloud', 'feels_like_celsius', 'feels_like_fahrenheit', 'visibility_km',
#        'visibility_miles', 'uv_index', 'gust_mph', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10', 'air_quality_us-epa-index',
#        'air_quality_gb-defra-index', 'moon_illumination'],
#       dtype='object')

# %%
weather_corr["latitude"].sort_values(ascending=False)
# Out:
# latitude                        1.000000
# air_quality_Nitrogen_dioxide    0.127028
# humidity                        0.119778
# wind_degree                     0.104342
# air_quality_Ozone               0.080944
# pressure_in                     0.071993
# pressure_mb                     0.071149
# air_quality_Sulphur_dioxide     0.032758
# moon_illumination               0.000016
# last_updated_epoch             -0.000265
# air_quality_us-epa-index       -0.005352
# air_quality_gb-defra-index     -0.008995
# visibility_miles               -0.009808
# visibility_km                  -0.010526
# longitude                      -0.013652
# precip_in                      -0.033135
# precip_mm                      -0.034173
# air_quality_PM2.5              -0.046834
# air_quality_PM10               -0.054657
# gust_kph                       -0.084009
# gust_mph                       -0.084055
# wind_mph                       -0.089537
# wind_kph                       -0.089568
# ...

# %% [markdown]
#    **from weather dataset**
#
#       * lattitude shows:
#            * air_quality_Nitrogen_dioxide have comparitively more +ve correlation
#            * temperature_fahrenheit have comparitively more -ve correlation

# %%
weather_corr["longitude"].sort_values(ascending=False)
# Out:
# longitude                       1.000000
# air_quality_gb-defra-index      0.179078
# air_quality_us-epa-index        0.175107
# air_quality_PM2.5               0.145561
# humidity                        0.135106
# air_quality_PM10                0.127850
# air_quality_Carbon_Monoxide     0.113466
# air_quality_Nitrogen_dioxide    0.093191
# air_quality_Sulphur_dioxide     0.075764
# cloud                           0.053223
# wind_degree                     0.002040
# visibility_km                   0.001348
# last_updated_epoch              0.000785
# moon_illumination              -0.000854
# visibility_miles               -0.003877
# pressure_in                    -0.006817
# pressure_mb                    -0.008029
# latitude                       -0.013652
# precip_mm                      -0.028194
# precip_in                      -0.028390
# gust_kph                       -0.035264
# gust_mph                       -0.035311
# wind_mph                       -0.125799
# ...

# %% [markdown]
# **from weather dataset**
#
#       * longitude shows:
#        * air_quality_gb-defra-index have comparitively more +ve correlation
#        * uv_index  have comparitively more -ve correlation

# %%
weather_corr["latitude"].sort_values(ascending=False)
# Out:
# latitude                        1.000000
# air_quality_Nitrogen_dioxide    0.127028
# humidity                        0.119778
# wind_degree                     0.104342
# air_quality_Ozone               0.080944
# pressure_in                     0.071993
# pressure_mb                     0.071149
# air_quality_Sulphur_dioxide     0.032758
# moon_illumination               0.000016
# last_updated_epoch             -0.000265
# air_quality_us-epa-index       -0.005352
# air_quality_gb-defra-index     -0.008995
# visibility_miles               -0.009808
# visibility_km                  -0.010526
# longitude                      -0.013652
# precip_in                      -0.033135
# precip_mm                      -0.034173
# air_quality_PM2.5              -0.046834
# air_quality_PM10               -0.054657
# gust_kph                       -0.084009
# gust_mph                       -0.084055
# wind_mph                       -0.089537
# wind_kph                       -0.089568
# ...

# %% [markdown]
# **from weather dataset**
#
#     * lattitude shows:
#        * air_quality_Nitrogen_dioxide have comparitively more +ve correlation
#        * temperature_fahrenheit have comparitively more -ve correlation

# %%
weather_corr["last_updated_epoch"].sort_values(ascending=False)
# Out:
# last_updated_epoch              1.000000
# pressure_in                     0.076631
# pressure_mb                     0.075125
# air_quality_us-epa-index        0.070022
# air_quality_gb-defra-index      0.069589
# air_quality_PM10                0.056908
# air_quality_Nitrogen_dioxide    0.042123
# air_quality_PM2.5               0.040730
# air_quality_Carbon_Monoxide     0.024706
# wind_kph                        0.022797
# wind_mph                        0.022586
# wind_degree                     0.020470
# air_quality_Sulphur_dioxide     0.014845
# gust_mph                        0.004380
# gust_kph                        0.004334
# longitude                       0.000785
# latitude                       -0.000265
# air_quality_Ozone              -0.002390
# visibility_km                  -0.008903
# visibility_miles               -0.010427
# cloud                          -0.022239
# humidity                       -0.033313
# precip_in                      -0.033960
# ...

# %% [markdown]
# **from weather dataset**
#
#      * last_updated_epoch shows:
#        * pressure_in have comparitively more +ve correlation
#        * moon_illumination  have comparitively more -ve correlation

# %%
weather_corr["temperature_celsius"].sort_values(ascending=False)
# Out:
# temperature_celsius             1.000000
# temperature_fahrenheit          0.999998
# feels_like_fahrenheit           0.971986
# feels_like_celsius              0.971978
# uv_index                        0.398819
# gust_mph                        0.126054
# gust_kph                        0.125998
# air_quality_PM10                0.117244
# air_quality_Ozone               0.113384
# air_quality_gb-defra-index      0.109744
# air_quality_us-epa-index        0.107174
# cloud                           0.078305
# visibility_km                   0.071546
# wind_mph                        0.067190
# wind_kph                        0.066926
# air_quality_PM2.5               0.061826
# visibility_miles                0.054433
# precip_mm                       0.053229
# precip_in                       0.053039
# air_quality_Carbon_Monoxide     0.045992
# air_quality_Sulphur_dioxide     0.042028
# moon_illumination              -0.001496
# air_quality_Nitrogen_dioxide   -0.038105
# ...

# %% [markdown]
# **from weather dataset**
#
#      * temperature_celsius shows:
#         *temperature_fahrenheit,feels_like_fahrenheit,feels_like_celsius have comparitively more +ve correlation
#         * pressure_in have comparitively more -ve correlation

# %%
weather_corr["temperature_fahrenheit"].sort_values(ascending=False)
# Out:
# temperature_fahrenheit          1.000000
# temperature_celsius             0.999998
# feels_like_fahrenheit           0.971980
# feels_like_celsius              0.971971
# uv_index                        0.398793
# gust_mph                        0.126042
# gust_kph                        0.125986
# air_quality_PM10                0.117267
# air_quality_Ozone               0.113376
# air_quality_gb-defra-index      0.109792
# air_quality_us-epa-index        0.107217
# cloud                           0.078279
# visibility_km                   0.071555
# wind_mph                        0.067179
# wind_kph                        0.066914
# air_quality_PM2.5               0.061842
# visibility_miles                0.054443
# precip_mm                       0.053204
# precip_in                       0.053014
# air_quality_Carbon_Monoxide     0.046000
# air_quality_Sulphur_dioxide     0.042020
# moon_illumination              -0.001484
# air_quality_Nitrogen_dioxide   -0.038101
# ...

# %% [markdown]
# **from weather dataset**
#
#       temperature_fahrenheit shows:
#         *temperature_celsius,feels_like_fahrenheit,feels_like_celsius have comparitively more +ve correlation
#         * pressure_in have comparitively more -ve correlation

# %%
weather_corr["wind_mph"].sort_values(ascending=False)
# Out:
# wind_mph                        1.000000
# wind_kph                        0.999965
# gust_mph                        0.557835
# gust_kph                        0.557822
# air_quality_Ozone               0.208514
# uv_index                        0.163542
# cloud                           0.158747
# wind_degree                     0.111613
# temperature_celsius             0.067190
# temperature_fahrenheit          0.067179
# feels_like_celsius              0.065552
# feels_like_fahrenheit           0.065491
# visibility_miles                0.061144
# visibility_km                   0.051884
# precip_mm                       0.032442
# precip_in                       0.031381
# last_updated_epoch              0.022586
# moon_illumination              -0.002942
# humidity                       -0.082823
# latitude                       -0.089537
# air_quality_Carbon_Monoxide    -0.101032
# air_quality_Sulphur_dioxide    -0.106370
# air_quality_PM10               -0.106509
# ...

# %% [markdown]
# **from weather dataset**
#
#      wind_mph shows:
#         *wind_kph have comparitively more +ve correlation
#         * air_quality_us-epa-index have comparitively more -ve correlation

# %%
weather_corr["wind_kph"].sort_values(ascending=False)
# Out:
# wind_kph                        1.000000
# wind_mph                        0.999965
# gust_mph                        0.557742
# gust_kph                        0.557727
# air_quality_Ozone               0.208757
# uv_index                        0.163881
# cloud                           0.158884
# wind_degree                     0.110591
# temperature_celsius             0.066926
# temperature_fahrenheit          0.066914
# feels_like_celsius              0.065311
# feels_like_fahrenheit           0.065250
# visibility_miles                0.061050
# visibility_km                   0.051782
# precip_mm                       0.032373
# precip_in                       0.031313
# last_updated_epoch              0.022797
# moon_illumination              -0.003215
# humidity                       -0.082949
# latitude                       -0.089568
# air_quality_Carbon_Monoxide    -0.101174
# air_quality_Sulphur_dioxide    -0.106457
# air_quality_PM10               -0.106752
# ...

# %% [markdown]
# **from weather dataset**
#
#      "wind_kph shows:
#         *wind_mph have comparitively more +ve correlation
#         * air_quality_us-epa-index more -ve correlation

# %%
weather_corr["wind_degree"].sort_values(ascending=False)
# Out:
# wind_degree                     1.000000
# wind_mph                        0.111613
# wind_kph                        0.110591
# latitude                        0.104342
# air_quality_Ozone               0.056295
# humidity                        0.046372
# gust_kph                        0.041776
# gust_mph                        0.041710
# cloud                           0.028947
# precip_in                       0.026813
# precip_mm                       0.026408
# last_updated_epoch              0.020470
# moon_illumination               0.015274
# air_quality_PM10                0.005018
# longitude                       0.002040
# air_quality_Carbon_Monoxide     0.000429
# air_quality_PM2.5              -0.006300
# air_quality_us-epa-index       -0.008910
# visibility_km                  -0.009153
# visibility_miles               -0.010591
# air_quality_Nitrogen_dioxide   -0.013860
# air_quality_gb-defra-index     -0.014754
# air_quality_Sulphur_dioxide    -0.025622
# ...

# %% [markdown]
# **from weather dataset**
#
#      wind_degree shows:
#         * wind_mph have comparitively more  +ve correlation(strength is less)
#         * uv_index  have comparitively more -ve correlation

# %%
weather_corr["pressure_mb"].sort_values(ascending=False)
# Out:
# pressure_mb                     1.000000
# pressure_in                     0.999496
# last_updated_epoch              0.075125
# latitude                        0.071149
# visibility_miles                0.050822
# air_quality_Nitrogen_dioxide    0.039830
# visibility_km                   0.039663
# moon_illumination               0.036143
# humidity                        0.016554
# longitude                      -0.008029
# air_quality_Sulphur_dioxide    -0.031512
# wind_degree                    -0.033534
# air_quality_Carbon_Monoxide    -0.046359
# air_quality_PM2.5              -0.058255
# precip_in                      -0.074512
# precip_mm                      -0.075541
# air_quality_Ozone              -0.076925
# air_quality_us-epa-index       -0.084099
# air_quality_PM10               -0.084986
# air_quality_gb-defra-index     -0.097835
# cloud                          -0.165108
# wind_kph                       -0.178972
# wind_mph                       -0.178988
# ...

# %% [markdown]
# **from weather dataset**
#
#      pressure_mb shows:
#         * pressure_in have comparitively more +ve correlation
#         * temperature_fahrenheit have comparitively more -ve correlation

# %%
weather_corr["pressure_in"].sort_values(ascending=False)
# Out:
# pressure_in                     1.000000
# pressure_mb                     0.999496
# last_updated_epoch              0.076631
# latitude                        0.071993
# visibility_miles                0.048700
# air_quality_Nitrogen_dioxide    0.040715
# visibility_km                   0.037379
# moon_illumination               0.036865
# humidity                        0.017237
# longitude                      -0.006817
# air_quality_Sulphur_dioxide    -0.030598
# wind_degree                    -0.033660
# air_quality_Carbon_Monoxide    -0.046329
# air_quality_PM2.5              -0.057858
# precip_in                      -0.074307
# precip_mm                      -0.075356
# air_quality_Ozone              -0.077250
# air_quality_us-epa-index       -0.083056
# air_quality_PM10               -0.084263
# air_quality_gb-defra-index     -0.096699
# cloud                          -0.165628
# wind_kph                       -0.179335
# wind_mph                       -0.179342
# ...

# %% [markdown]
# **from weather dataset**
#
#      pressure_in shows:
#         * pressure_mb have comparitively more +ve correlation
#         * temperature_fahrenheit have comparitively more -ve correlation

# %%
weather_corr["precip_mm"].sort_values(ascending=False)
# Out:
# precip_mm                       1.000000
# precip_in                       0.999240
# cloud                           0.187404
# humidity                        0.119271
# feels_like_celsius              0.082015
# feels_like_fahrenheit           0.082000
# temperature_celsius             0.053229
# temperature_fahrenheit          0.053204
# moon_illumination               0.049170
# uv_index                        0.038769
# gust_mph                        0.036171
# gust_kph                        0.036132
# wind_mph                        0.032442
# wind_kph                        0.032373
# wind_degree                     0.026408
# air_quality_Sulphur_dioxide     0.012548
# air_quality_Carbon_Monoxide    -0.005635
# visibility_km                  -0.018121
# air_quality_Nitrogen_dioxide   -0.025116
# visibility_miles               -0.025341
# longitude                      -0.028194
# air_quality_PM2.5              -0.029645
# air_quality_Ozone              -0.033076
# ...

# %% [markdown]
# **from weather dataset**
#
#     precip_mm shows:
#         * precip_in have comparitively more +ve correlation
#         * pressure_mb have comparitively more -ve correlation

# %%
weather_corr["humidity"].sort_values(ascending=False)
# Out:
# humidity                        1.000000
# cloud                           0.365994
# longitude                       0.135106
# latitude                        0.119778
# precip_mm                       0.119271
# precip_in                       0.117617
# air_quality_Carbon_Monoxide     0.065515
# wind_degree                     0.046372
# air_quality_PM2.5               0.031789
# moon_illumination               0.025086
# pressure_in                     0.017237
# pressure_mb                     0.016554
# last_updated_epoch             -0.033313
# air_quality_PM10               -0.042075
# air_quality_gb-defra-index     -0.044268
# air_quality_us-epa-index       -0.048794
# gust_mph                       -0.049949
# gust_kph                       -0.050005
# air_quality_Nitrogen_dioxide   -0.064996
# wind_mph                       -0.082823
# wind_kph                       -0.082949
# air_quality_Sulphur_dioxide    -0.109724
# uv_index                       -0.117702
# ...

# %% [markdown]
# **from weather dataset**
#
#      humidity shows:
#         *none of the points are showing correlation as the values are more close to 0

# %%
weather_corr["visibility_miles"].sort_values(ascending=False)
# Out:
# visibility_miles                1.000000
# visibility_km                   0.991276
# uv_index                        0.190137
# gust_mph                        0.115495
# gust_kph                        0.115389
# air_quality_Ozone               0.073535
# wind_mph                        0.061144
# wind_kph                        0.061050
# feels_like_fahrenheit           0.059195
# feels_like_celsius              0.059193
# temperature_fahrenheit          0.054443
# temperature_celsius             0.054433
# pressure_mb                     0.050822
# pressure_in                     0.048700
# cloud                           0.040740
# moon_illumination               0.003449
# longitude                      -0.003877
# latitude                       -0.009808
# last_updated_epoch             -0.010427
# wind_degree                    -0.010591
# precip_mm                      -0.025341
# precip_in                      -0.025535
# air_quality_Sulphur_dioxide    -0.089614
# ...

# %% [markdown]
# **from weather dataset**
#
#      visibility_miles shows:
#         * visibility_km  have comparitively more +ve correlation
#         * air_quality_us-epa-index have comparitively more -ve correlation

# %%
weather_corr["uv_index"].sort_values(ascending=False)
# Out:
# uv_index                        1.000000
# feels_like_celsius              0.426020
# feels_like_fahrenheit           0.425984
# temperature_celsius             0.398819
# temperature_fahrenheit          0.398793
# visibility_km                   0.199564
# cloud                           0.199074
# visibility_miles                0.190137
# wind_kph                        0.163881
# wind_mph                        0.163542
# air_quality_Ozone               0.127611
# air_quality_Sulphur_dioxide     0.055695
# precip_mm                       0.038769
# precip_in                       0.038667
# gust_mph                        0.033290
# gust_kph                        0.033206
# moon_illumination              -0.031148
# air_quality_Carbon_Monoxide    -0.037091
# last_updated_epoch             -0.042978
# wind_degree                    -0.054370
# air_quality_PM2.5              -0.065827
# air_quality_Nitrogen_dioxide   -0.075031
# air_quality_PM10               -0.092903
# ...

# %% [markdown]
# **from weather dataset**
#
#     uv_index shows:
#         *

# %%
weather_corr["gust_mph"].sort_values(ascending=False)
# Out:
# gust_mph                        1.000000
# gust_kph                        0.999987
# wind_mph                        0.557835
# wind_kph                        0.557742
# air_quality_Ozone               0.239271
# temperature_celsius             0.126054
# temperature_fahrenheit          0.126042
# visibility_miles                0.115495
# cloud                           0.112338
# visibility_km                   0.107519
# feels_like_celsius              0.101972
# feels_like_fahrenheit           0.101940
# wind_degree                     0.041710
# precip_mm                       0.036171
# precip_in                       0.033808
# uv_index                        0.033290
# moon_illumination               0.018499
# last_updated_epoch              0.004380
# longitude                      -0.035311
# humidity                       -0.049949
# latitude                       -0.084055
# air_quality_PM10               -0.097355
# air_quality_PM2.5              -0.149959
# ...

# %% [markdown]
# **from weather dataset**
#
#     gust_mph shows:
#         * gust_kph have comparitively more +ve correlation
#         * air_quality_Nitrogen_dioxide have comparitively more -ve correlation

# %%
weather_corr["gust_kph"].sort_values(ascending=False)
# Out:
# gust_kph                        1.000000
# gust_mph                        0.999987
# wind_mph                        0.557822
# wind_kph                        0.557727
# air_quality_Ozone               0.239258
# temperature_celsius             0.125998
# temperature_fahrenheit          0.125986
# visibility_miles                0.115389
# cloud                           0.112272
# visibility_km                   0.107400
# feels_like_celsius              0.101886
# feels_like_fahrenheit           0.101854
# wind_degree                     0.041776
# precip_mm                       0.036132
# precip_in                       0.033768
# uv_index                        0.033206
# moon_illumination               0.018636
# last_updated_epoch              0.004334
# longitude                      -0.035264
# humidity                       -0.050005
# latitude                       -0.084009
# air_quality_PM10               -0.097272
# air_quality_PM2.5              -0.149876
# ...

# %% [markdown]
# **from weather dataset**
#
#     gust_kph shows:
#         * gust_mph have comparitively more +ve correlation
#         * gust_mph have comparitively more -ve correlation

# %%
weather_corr["cloud"].sort_values(ascending=False)
# Out:
# cloud                           1.000000
# humidity                        0.365994
# uv_index                        0.199074
# precip_mm                       0.187404
# precip_in                       0.183851
# wind_kph                        0.158884
# wind_mph                        0.158747
# feels_like_fahrenheit           0.114280
# feels_like_celsius              0.114242
# gust_mph                        0.112338
# gust_kph                        0.112272
# temperature_celsius             0.078305
# temperature_fahrenheit          0.078279
# visibility_km                   0.059425
# longitude                       0.053223
# visibility_miles                0.040740
# wind_degree                     0.028947
# moon_illumination               0.023103
# air_quality_Carbon_Monoxide    -0.013997
# last_updated_epoch             -0.022239
# air_quality_Sulphur_dioxide    -0.072965
# air_quality_PM2.5              -0.083601
# air_quality_Ozone              -0.100927
# ...

# %% [markdown]
# **from weather dataset**
#
#      cloud shows:
#         *

# %%
weather_corr["feels_like_celsius"].sort_values(ascending=False)
# Out:
# feels_like_celsius              1.000000
# feels_like_fahrenheit           0.999995
# temperature_celsius             0.971978
# temperature_fahrenheit          0.971971
# uv_index                        0.426020
# cloud                           0.114242
# gust_mph                        0.101972
# gust_kph                        0.101886
# air_quality_Ozone               0.093382
# air_quality_PM10                0.086554
# air_quality_gb-defra-index      0.085837
# precip_mm                       0.082015
# precip_in                       0.081609
# air_quality_us-epa-index        0.080190
# visibility_km                   0.076163
# wind_mph                        0.065552
# wind_kph                        0.065311
# visibility_miles                0.059193
# air_quality_PM2.5               0.044970
# air_quality_Sulphur_dioxide     0.043142
# air_quality_Carbon_Monoxide     0.039667
# moon_illumination               0.004392
# wind_degree                    -0.047073
# ...

# %% [markdown]
# **from weather dataset**
#
#      feels_like_celsius shows:
#         * feels_like_fahrenheit,feels_like_celsius,temperature_fahrenheit have comparitively more +ve correlation
#         * pressure_in have comparitively more -ve correlation

# %%
weather_corr["feels_like_fahrenheit"].sort_values(ascending=False)
# Out:
# feels_like_fahrenheit           1.000000
# feels_like_celsius              0.999995
# temperature_celsius             0.971986
# temperature_fahrenheit          0.971980
# uv_index                        0.425984
# cloud                           0.114280
# gust_mph                        0.101940
# gust_kph                        0.101854
# air_quality_Ozone               0.093339
# air_quality_PM10                0.086517
# air_quality_gb-defra-index      0.085836
# precip_mm                       0.082000
# precip_in                       0.081594
# air_quality_us-epa-index        0.080176
# visibility_km                   0.076163
# wind_mph                        0.065491
# wind_kph                        0.065250
# visibility_miles                0.059195
# air_quality_PM2.5               0.044913
# air_quality_Sulphur_dioxide     0.043112
# air_quality_Carbon_Monoxide     0.039642
# moon_illumination               0.004424
# wind_degree                    -0.047099
# ...

# %% [markdown]
# **from weather dataset**
#
#      feels_like_fahrenheit shows:
#         * feels_like_celsius,temperature_celsius,temperature_fahrenheit have comparitively more +ve correlation
#         * pressure_in have comparitively more -ve correlation

# %%
weather_corr["visibility_km"].sort_values(ascending=False)
# Out:
# visibility_km                   1.000000
# visibility_miles                0.991276
# uv_index                        0.199564
# gust_mph                        0.107519
# gust_kph                        0.107400
# feels_like_celsius              0.076163
# feels_like_fahrenheit           0.076163
# temperature_fahrenheit          0.071555
# temperature_celsius             0.071546
# air_quality_Ozone               0.066098
# cloud                           0.059425
# wind_mph                        0.051884
# wind_kph                        0.051782
# pressure_mb                     0.039663
# pressure_in                     0.037379
# longitude                       0.001348
# moon_illumination               0.001100
# last_updated_epoch             -0.008903
# wind_degree                    -0.009153
# latitude                       -0.010526
# precip_mm                      -0.018121
# precip_in                      -0.018244
# air_quality_Sulphur_dioxide    -0.085987
# ...

# %% [markdown]
# **from weather dataset**
#
#      visibility_km shows:
#         * visibility_miles have comparitively more +ve correlation
#         * air_quality_PM10 have comparitively more -ve correlation

# %%
weather_corr["air_quality_Carbon_Monoxide"].sort_values(ascending=False)
# Out:
# air_quality_Carbon_Monoxide     1.000000
# air_quality_PM2.5               0.898766
# air_quality_PM10                0.753502
# air_quality_us-epa-index        0.558782
# air_quality_Nitrogen_dioxide    0.510306
# air_quality_gb-defra-index      0.481637
# air_quality_Sulphur_dioxide     0.387185
# longitude                       0.113466
# humidity                        0.065515
# temperature_fahrenheit          0.046000
# temperature_celsius             0.045992
# feels_like_celsius              0.039667
# feels_like_fahrenheit           0.039642
# last_updated_epoch              0.024706
# wind_degree                     0.000429
# precip_in                      -0.005461
# precip_mm                      -0.005635
# moon_illumination              -0.009442
# cloud                          -0.013997
# uv_index                       -0.037091
# pressure_in                    -0.046329
# pressure_mb                    -0.046359
# wind_mph                       -0.101032
# ...

# %% [markdown]
# **from weather dataset**
#
#     air_quality_Carbon_Monoxide shows:
#         * air_quality_PM2.5  have comparitively more +ve correlation
#         * air_quality_Ozone have comparitively more -ve correlation

# %%
weather_corr["air_quality_Ozone"].sort_values(ascending=False)
# Out:
# air_quality_Ozone               1.000000
# gust_mph                        0.239271
# gust_kph                        0.239258
# wind_kph                        0.208757
# wind_mph                        0.208514
# uv_index                        0.127611
# temperature_celsius             0.113384
# temperature_fahrenheit          0.113376
# feels_like_celsius              0.093382
# feels_like_fahrenheit           0.093339
# latitude                        0.080944
# visibility_miles                0.073535
# visibility_km                   0.066098
# wind_degree                     0.056295
# last_updated_epoch             -0.002390
# precip_in                      -0.032756
# moon_illumination              -0.032924
# precip_mm                      -0.033076
# air_quality_Sulphur_dioxide    -0.039942
# air_quality_PM10               -0.065344
# air_quality_gb-defra-index     -0.070505
# air_quality_us-epa-index       -0.075899
# pressure_mb                    -0.076925
# ...

# %% [markdown]
# **from weather dataset**
#
#      air_quality_Ozone shows:
#         *

# %%
weather_corr["air_quality_Nitrogen_dioxide"].sort_values(ascending=False)
# Out:
# air_quality_Nitrogen_dioxide    1.000000
# air_quality_Sulphur_dioxide     0.702992
# air_quality_us-epa-index        0.514550
# air_quality_Carbon_Monoxide     0.510306
# air_quality_PM2.5               0.507385
# air_quality_gb-defra-index      0.480057
# air_quality_PM10                0.422014
# latitude                        0.127028
# longitude                       0.093191
# last_updated_epoch              0.042123
# pressure_in                     0.040715
# pressure_mb                     0.039830
# moon_illumination              -0.007295
# wind_degree                    -0.013860
# precip_in                      -0.024093
# precip_mm                      -0.025116
# temperature_fahrenheit         -0.038101
# temperature_celsius            -0.038105
# feels_like_celsius             -0.049223
# feels_like_fahrenheit          -0.049272
# humidity                       -0.064996
# uv_index                       -0.075031
# visibility_km                  -0.111254
# ...

# %% [markdown]
# **from weather dataset**
#
#      air_quality_Nitrogen_dioxide shows:
#         * air_quality_Sulphur_dioxide have comparitively more +ve correlation
#         * air_quality_Ozone have comparitively more -ve correlation

# %%
weather_corr["air_quality_Sulphur_dioxide"].sort_values(ascending=False)
# Out:
# air_quality_Sulphur_dioxide     1.000000
# air_quality_Nitrogen_dioxide    0.702992
# air_quality_us-epa-index        0.441060
# air_quality_gb-defra-index      0.425334
# air_quality_PM2.5               0.403013
# air_quality_Carbon_Monoxide     0.387185
# air_quality_PM10                0.344048
# longitude                       0.075764
# uv_index                        0.055695
# feels_like_celsius              0.043142
# feels_like_fahrenheit           0.043112
# temperature_celsius             0.042028
# temperature_fahrenheit          0.042020
# latitude                        0.032758
# last_updated_epoch              0.014845
# precip_in                       0.013249
# precip_mm                       0.012548
# moon_illumination              -0.009402
# wind_degree                    -0.025622
# pressure_in                    -0.030598
# pressure_mb                    -0.031512
# air_quality_Ozone              -0.039942
# cloud                          -0.072965
# ...

# %% [markdown]
# **from weather dataset**
#
#     air_quality_Sulphur_dioxide shows:
#         * air_quality_Nitrogen_dioxide have comparitively more +ve correlation
#         * gust_mph  have comparitively more -ve correlation

# %%
weather_corr["air_quality_PM2.5"].sort_values(ascending=False)
# Out:
# air_quality_PM2.5               1.000000
# air_quality_PM10                0.909002
# air_quality_Carbon_Monoxide     0.898766
# air_quality_us-epa-index        0.731761
# air_quality_gb-defra-index      0.648959
# air_quality_Nitrogen_dioxide    0.507385
# air_quality_Sulphur_dioxide     0.403013
# longitude                       0.145561
# temperature_fahrenheit          0.061842
# temperature_celsius             0.061826
# feels_like_celsius              0.044970
# feels_like_fahrenheit           0.044913
# last_updated_epoch              0.040730
# humidity                        0.031789
# wind_degree                    -0.006300
# moon_illumination              -0.012835
# precip_in                      -0.029186
# precip_mm                      -0.029645
# latitude                       -0.046834
# pressure_in                    -0.057858
# pressure_mb                    -0.058255
# uv_index                       -0.065827
# cloud                          -0.083601
# ...

# %% [markdown]
# **from weather dataset**
#
#     air_quality_PM2.5 shows:
#         * air_quality_PM10 ,air_quality_Carbon_Monoxide, have comparitively more +ve correlation
#         * visibility_miles have comparitively more -ve correlation

# %%
weather_corr["air_quality_PM10"].sort_values(ascending=False)
# Out:
# air_quality_PM10                1.000000
# air_quality_PM2.5               0.909002
# air_quality_Carbon_Monoxide     0.753502
# air_quality_us-epa-index        0.726187
# air_quality_gb-defra-index      0.657109
# air_quality_Nitrogen_dioxide    0.422014
# air_quality_Sulphur_dioxide     0.344048
# longitude                       0.127850
# temperature_fahrenheit          0.117267
# temperature_celsius             0.117244
# feels_like_celsius              0.086554
# feels_like_fahrenheit           0.086517
# last_updated_epoch              0.056908
# wind_degree                     0.005018
# moon_illumination              -0.012189
# precip_in                      -0.040297
# precip_mm                      -0.040789
# humidity                       -0.042075
# latitude                       -0.054657
# air_quality_Ozone              -0.065344
# pressure_in                    -0.084263
# pressure_mb                    -0.084986
# uv_index                       -0.092903
# ...

# %% [markdown]
# **from weather dataset**
#
#      air_quality_PM10 shows:
#         * air_quality_PM2.5  have comparitively more +ve correlation
#         * visibility_miles have comparitively more -ve correlation

# %%
weather_corr["air_quality_us-epa-index"].sort_values(ascending=False)
# Out:
# air_quality_us-epa-index        1.000000
# air_quality_gb-defra-index      0.942991
# air_quality_PM2.5               0.731761
# air_quality_PM10                0.726187
# air_quality_Carbon_Monoxide     0.558782
# air_quality_Nitrogen_dioxide    0.514550
# air_quality_Sulphur_dioxide     0.441060
# longitude                       0.175107
# temperature_fahrenheit          0.107217
# temperature_celsius             0.107174
# feels_like_celsius              0.080190
# feels_like_fahrenheit           0.080176
# last_updated_epoch              0.070022
# latitude                       -0.005352
# wind_degree                    -0.008910
# moon_illumination              -0.025699
# precip_in                      -0.043458
# precip_mm                      -0.044195
# humidity                       -0.048794
# air_quality_Ozone              -0.075899
# pressure_in                    -0.083056
# pressure_mb                    -0.084099
# uv_index                       -0.117452
# ...

# %% [markdown]
# **from weather dataset**
#
#      air_quality_us-epa-index shows:
#         *air_quality_gb-defra-index  have comparitively more +ve correlation
#         * visibility_miles have comparitively more -ve correlation

# %%
weather_corr["air_quality_gb-defra-index"].sort_values(ascending=False)
# Out:
# air_quality_gb-defra-index      1.000000
# air_quality_us-epa-index        0.942991
# air_quality_PM10                0.657109
# air_quality_PM2.5               0.648959
# air_quality_Carbon_Monoxide     0.481637
# air_quality_Nitrogen_dioxide    0.480057
# air_quality_Sulphur_dioxide     0.425334
# longitude                       0.179078
# temperature_fahrenheit          0.109792
# temperature_celsius             0.109744
# feels_like_celsius              0.085837
# feels_like_fahrenheit           0.085836
# last_updated_epoch              0.069589
# latitude                       -0.008995
# wind_degree                    -0.014754
# moon_illumination              -0.023866
# precip_in                      -0.038479
# precip_mm                      -0.038986
# humidity                       -0.044268
# air_quality_Ozone              -0.070505
# pressure_in                    -0.096699
# pressure_mb                    -0.097835
# uv_index                       -0.111955
# ...

# %% [markdown]
# **from weather dataset**
#
#      air_quality_gb-defra-index shows:
#         * air_quality_us-epa-index have comparitively more +ve correlation
#         * visibility_miles have comparitively more -ve correlation

# %%
weather_corr["moon_illumination"].sort_values(ascending=False)
# Out:
# moon_illumination               1.000000
# precip_mm                       0.049170
# precip_in                       0.048604
# pressure_in                     0.036865
# pressure_mb                     0.036143
# humidity                        0.025086
# cloud                           0.023103
# gust_kph                        0.018636
# gust_mph                        0.018499
# wind_degree                     0.015274
# feels_like_fahrenheit           0.004424
# feels_like_celsius              0.004392
# visibility_miles                0.003449
# visibility_km                   0.001100
# latitude                        0.000016
# longitude                      -0.000854
# temperature_fahrenheit         -0.001484
# temperature_celsius            -0.001496
# wind_mph                       -0.002942
# wind_kph                       -0.003215
# air_quality_Nitrogen_dioxide   -0.007295
# air_quality_Sulphur_dioxide    -0.009402
# air_quality_Carbon_Monoxide    -0.009442
# ...

# %% [markdown]
# **from weather dataset**
#
#      moon_illumination shows:
#         *none of the points are showing correlation as the values are more close to 0
